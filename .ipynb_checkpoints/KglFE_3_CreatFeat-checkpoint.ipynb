# %% [markdown]
# # Kaggle Feature Engineering microcurse
# - Better features make better models.
# - Discover how to get the most out of your data
# - https://www.kaggle.com/learn/feature-engineering

# %% [markdown]
# ## 3.- Creating Features
# - Transform features with Pandas to suit your model.

# %% [markdown]
# ### Intro
# - Once you've identified a set of features with some potential, it's time to start developing them

# %% [markdown]
# - Number of common transformations you can do entirely in Pandas
# - Datasets: US Traffic Acccidents, 1985 Automobiles, Concrete Formulations, Customer Lifetime Value.

# %%
### Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import requests
import zipfile as zfm
import io

# %%
# plt and sns defaults settings
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
sns.set_style('whitegrid')

# %%
### Write url w/zipfile path

# Data that define repo and filename w/path
ro = 'jmonti-gh'                  # repo_owner
rn = 'Datasets'                   # repo_name
zipfln = 'FE_CourseData_1.zip'
datasets = ('accidents.csv', 'autos.csv', 'concrete.csv', 'customer.csv')
dataframes = []


# Data necesary If a proxy is used
proxies = {
  'http': 'http://jorge.monti:jorgemonti2009@172.16.1.49:3128',
  'https': 'http://jorge.monti:jorgemonti2009@172.16.1.49:3128'    # https://jorge.monti:jorgemonti2009@172.16.1.49:3128
}

# url where to obtain the response
url = f'https://raw.githubusercontent.com/{ro}/{rn}/main/{zipfln}'

# %%
### try-except block to get the zipfile containing the dataset
try:
    r = requests.get(url)
    print('No Proxy needed')
except OSError as oe:
    if 'ProxyError' in str(oe):
        r = requests.get(url, proxies=proxies)
        print('Proxy used!')
    else:
        ln = '-' * 5 + '\n'
        for er in [oe, oe.args]:
            print(ln, er, '\nType: ', type(er), sep='')
# Out:
# No Proxy needed

# %%
### Read the zipfile and load the datasets
with zfm.ZipFile(io.BytesIO(r.content)) as zf:
    print(zf.namelist())
    for dset in datasets:
        dataframes.append(pd.read_csv(zf.open(dset)))

accidents, autos = dataframes[0], dataframes[1]
concrete, customer = dataframes[2], dataframes[3]

# print(df.shape)
# df.iloc[[0, 9, -9, -1]]
# Out:
# ['abalone.csv', 'accidents.csv', 'airbnb.csv', 'ames.csv', 'autos.csv', 'bike-sharing.csv', 'caravan.csv', 'concrete.csv', 'customer.csv', 'DataDocumentation.txt']

# %% [markdown]
# #### Tips on Discovering New Features

# %% [markdown]
# - Understand the features. Refer to yout dataset's *data documentation*, if available.
# - Research the problem domain to acquiere __domain knowledge__. Ex. research in Wikipedia or scholar.google.com.
# - Study previous work: https://www.kaggle.com/code/sudalairajkumar/winning-solutions-of-kaggle-competitions/notebook
# - Use data visualization

# %% [markdown]
# ### Mathematical Transforms

# %% [markdown]
# Relationships among numerical features are often expressed through mathematical formulas, which you'll frequently come across as part of your domain research. __*In Pandas, you can apply arithmetic operations to columns just as if they were ordinary numbers.*__

# %% [markdown]
# #### In the Automobile dataset are features describing a car's engine.

# %% [markdown]
# Research yields a variety of formulas for creating potentially useful new features. The "stroke ratio", for instance, is a measure of how efficient an engine is versus how performant:

# %%
autos["stroke_ratio"] = autos.stroke / autos.bore
# autos[["stroke", "bore", "stroke_ratio"]].head()
autos[["stroke", "bore", "stroke_ratio"]].iloc[[0, 5, 9, -9, -1]]
# Out:
#      stroke  bore  stroke_ratio
# 0      2.68  3.47      0.772334
# 5      3.40  3.19      1.065831
# 9      2.80  3.50      0.800000
# 184    3.15  3.78      0.833333
# 192    3.15  3.78      0.833333

# %% [markdown]
# The more complicated a combination is, the more difficult it will be for a model to learn, like this formula for an engine's "displacement", a measure of its power:

# %%
autos["displacement"] = (
    np.pi * ((0.5 * autos.bore) ** 2) * autos.stroke * autos.num_of_cylinders
)

# %% [markdown]
# #### The distribution of WindSpeed in US Accidents is highly skewed

# %% [markdown]
# Data visualization can suggest transformations, often a "reshaping" of a feature through powers or logarithms. The distribution of WindSpeed in US Accidents is highly skewed, for instance. In this case the logarithm is effective at normalizing it:

# %%
# If the fuature has 0.0 values, use np.log1p (log(1+x) instead of np.log
accidents['WindSpeed'].sort_values()
# Out:
# 49944      0.0
# 12767      0.0
# 12766      0.0
# 30163      0.0
# 69659      0.0
#          ...
# 7317     114.0
# 97254    123.1
# 32125    230.0
# 92909    518.0
# 16533    822.8
# Name: WindSpeed, Length: 100000, dtype: float64

# %%
# New feature in a logarithm scale
accidents['LogWindSpeed'] = accidents.WindSpeed.apply(np.log1p)
accidents['LogWindSpeed'].sort_values()
# Out:
# 49944    0.000000
# 12767    0.000000
# 12766    0.000000
# 30163    0.000000
# 69659    0.000000
#            ...
# 7317     4.744932
# 97254    4.821088
# 32125    5.442418
# 92909    6.251904
# 16533    6.713928
# Name: LogWindSpeed, Length: 100000, dtype: float64

# %%
# Plot a comparison
fig, axs = plt.subplots(1, 2, figsize=(8, 3))
sns.kdeplot(accidents.WindSpeed, fill=True, ax=axs[0])
sns.kdeplot(accidents.LogWindSpeed, fill=True, ax=axs[1]);

# %% [markdown]
# Check out our lesson on normalization in Data Cleaning where you'll also learn about the Box-Cox transformation, a very general kind of normalizer.
# - https://www.kaggle.com/code/alexisbcook/scaling-and-normalization/tutorial
# - https://www.kaggle.com/learn/data-cleaning

# %% [markdown]
# ### Counts

# %% [markdown]
# - Features describing the presence or absence of something often come in sets, the set of risk factors for a disease, say. You can aggregate such features by creating a count.
# - These features will be binary (1 for Present, 0 for Absent) or boolean (True or False). In Python, booleans can be added up just as if they were integers.

# %% [markdown]
# #### Traffic Accidents - features to count
# - In Traffic Accidents are several features indicating whether some roadway object was near the accident. This will create a count of the total number of roadway features nearby using the sum method:

# %%
#accidents.info()
#accidents.select_dtypes('bool').columns
accidents[accidents.select_dtypes('bool').columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Amenity         100000 non-null  bool
#  1   Bump            100000 non-null  bool
#  2   Crossing        100000 non-null  bool
#  3   GiveWay         100000 non-null  bool
#  4   Junction        100000 non-null  bool
#  5   NoExit          100000 non-null  bool
#  6   Railway         100000 non-null  bool
#  7   Roundabout      100000 non-null  bool
#  8   Station         100000 non-null  bool
#  9   Stop            100000 non-null  bool
#  10  TrafficCalming  100000 non-null  bool
#  11  TrafficSignal   100000 non-null  bool
# dtypes: bool(12)
# memory usage: 1.1 MB

# %%
roadway_features = ["Amenity", "Bump", "Crossing", "GiveWay",
    "Junction", "NoExit", "Railway", "Roundabout", "Station", "Stop",
    "TrafficCalming", "TrafficSignal"]
accidents['RoadwayFeatures'] = accidents[roadway_features].sum(axis=1)

# #accidents[['Amenity', 'Stop', 'RoadwayFeatures']].loc[accidents.RoadwayFeatures > 4]\
# accidents[roadway_features + ["RoadwayFeatures"]].head(10)
# # accidents[roadway_features + ["RoadwayFeatures"]].loc[accidents.RoadwayFeatures > 4]\
# #             .head(5)
# # accidents[roadway_features + ["RoadwayFeatures"]].\
# #     loc[accidents.RoadwayFeatures > 2].iloc[[0, 5, 9, -9, -5, -1]]

display(accidents.RoadwayFeatures.value_counts())
# to see twoo rows of e/value of new col 'RoadwayFeautures'
auxdf = pd.DataFrame()
for i in range(accidents.RoadwayFeatures.max() + 1):
    # minidf = accidents[roadway_features + ['RoadwayFeatures']].\
    #         loc[accidents.RoadwayFeatures == i].iloc[[0,-1]]
    minidf = accidents[roadway_features + ['RoadwayFeatures']].\
            loc[accidents.RoadwayFeatures.eq(i)].iloc[[0,-1]]
    auxdf = pd.concat([auxdf, minidf])
auxdf
# Out:
# 0    70000
# 1    21924
# 2     6620
# 3     1243
# 4      192
# 5       19
# 6        2
# Name: RoadwayFeatures, dtype: int64
#        Amenity   Bump  Crossing  GiveWay  Junction  NoExit  Railway  \
# 0        False  False     False    False     False   False    False
# 99999    False  False     False    False     False   False    False
# 5        False  False     False    False      True   False    False
# 99998    False  False     False    False     False   False    False
# 7        False  False      True    False     False   False    False
# 99970    False  False      True    False     False   False    False
# 160      False  False      True     True     False   False    False
# 99877     True  False     False    False     False   False    False
# 1491      True  False      True    False     False   False     True
# 99697     True  False      True    False     False   False    False
# 5517      True  False      True    False     False   False     True
# ...

# %% [markdown]
# #### Concrete dataset - create boolean values
# You could also use a dataframe's built-in methods to create boolean values. In the Concrete dataset are the amounts of components in a concrete formulation. Many formulations lack one or more components (that is, the component has a value of 0). This will count how many components are in a formulation with the dataframe's built-in greater-than gt method:

# %%
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cement               1030 non-null   float64
#  1   BlastFurnaceSlag     1030 non-null   float64
#  2   FlyAsh               1030 non-null   float64
#  3   Water                1030 non-null   float64
#  4   Superplasticizer     1030 non-null   float64
#  5   CoarseAggregate      1030 non-null   float64
#  6   FineAggregate        1030 non-null   float64
#  7   Age                  1030 non-null   int64
#  8   CompressiveStrength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
components = [ "Cement", "BlastFurnaceSlag", "FlyAsh", "Water",
               "Superplasticizer", "CoarseAggregate", "FineAggregate"]
concrete['Components'] = concrete[components].gt(0).sum(axis=1)

#concrete[components + ['Components']].head(10)

display(concrete.Components.value_counts())
print(concrete.Components.value_counts().index)

# to see twoo rows of e/value of new col 'Components'
auxdf = pd.DataFrame()
for i in concrete.Components.value_counts().index:
    #print(i)
    minidf = concrete[components + ['Components']].\
            loc[concrete.Components.eq(i)].iloc[[0,-1]]
    auxdf = pd.concat([auxdf, minidf])
auxdf
# Out:
# 6    403
# 7    225
# 4    209
# 5    193
# Name: Components, dtype: int64
# Int64Index([6, 7, 4, 5], dtype='int64')
#       Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  \
# 70     374.0             189.2     0.0  170.1              10.1
# 1028   159.1             186.7     0.0  175.6              11.3
# 224    168.0              42.1   163.8  121.8               5.7
# 1029   260.9             100.5    78.3  200.6               8.6
# 9      475.0               0.0     0.0  228.0               0.0
# 828    522.0               0.0     0.0  146.0               0.0
# 0      540.0               0.0     0.0  162.0               2.5
# 994    374.3               0.0     0.0  190.2               6.7
#
#       CoarseAggregate  FineAggregate  Components
# 70              926.1          756.7           6
# 1028            989.6          788.9           6
# 224            1058.7          780.1           7
# 1029            864.5          761.5           7
# ...

# %% [markdown]
# ### Building-Up and Breaking-Down Features

# %% [markdown]
# Often you'll have complex strings that can usefully be broken into simpler pieces. Some common examples:
# - ID numbers: '123-45-6789'
# - Phone numbers: '(999) 555-0123'
# - Street addresses: '8241 Kaggle Ln., Goose City, NV'
# - Internet addresses: 'http://www.kaggle.com
# - Product codes: '0 36000 29145 2'
# - Dates and times: 'Mon Sep 30 07:06:05 2013'
#
# Features like these will often have some kind of structure that you can make use of. US phone numbers, for instance, have an area code (the '(999)' part) that tells you the location of the caller. As always, some research can pay off here.
# - The str accessor lets you apply string methods like split directly to columns.

# %% [markdown]
# #### Customer Lifetime Value

# %% [markdown]
# - From the Policy feature, we could separate the Type from the Level of coverage:
# - Build 'Type' & 'Level, from breaking 'Policy'

# %%
customer[["Type", "Level"]] = (  # Create two new features
    customer["Policy"]           # from the Policy feature
    .str                         # through the string accessor
    .split(" ", expand=True)     # by splitting on " "
                                 # and expanding the result into separate columns
)

customer[['Customer', 'Coverage', "Policy", "Type", "Level"]].head(5)
# Out:
#   Customer  Coverage        Policy       Type Level
# 0  BU79786     Basic  Corporate L3  Corporate    L3
# 1  QZ44356  Extended   Personal L3   Personal    L3
# 2  AI49188   Premium   Personal L3   Personal    L3
# 3  WW63253     Basic  Corporate L2  Corporate    L2
# 4  HB64268     Basic   Personal L1   Personal    L1

# %% [markdown]
# #### Autos - Compose Feature

# %% [markdown]
# You could also join simple features into a composed feature if you had reason to believe there was some interaction in the combination:

# %%
autos["make_and_style"] = autos["make"] + "_" + autos["body_style"]
autos[["make", "body_style", "make_and_style"]].head()
# Out:
#           make   body_style           make_and_style
# 0  alfa-romero  convertible  alfa-romero_convertible
# 1  alfa-romero  convertible  alfa-romero_convertible
# 2  alfa-romero    hatchback    alfa-romero_hatchback
# 3         audi        sedan               audi_sedan
# 4         audi        sedan               audi_sedan

# %% [markdown]
# ##### Elsewhere on Kaggle Learn
# There are a few other kinds of data we haven't talked about here that are especially rich in information. Fortunately, we've got you covered!
# - https://www.kaggle.com/code/alexisbcook/parsing-dates/tutorial
# - https://www.kaggle.com/learn/geospatial-analysis

# %% [markdown]
# ### Group Transforms

# %% [markdown]
# Finally we have Group transforms, which aggregate information across multiple rows grouped by some category. With a group transform you can create features like: "the average income of a person's state of residence," or "the proportion of movies released on a weekday, by genre." If you had discovered a category interaction, a group transform over that categry could be something good to investigate.

# %% [markdown]
# #### Customer - average income by state

# %% [markdown]
# Using an aggregation function, a group transform combines two features: a categorical feature that provides the grouping and another feature whose values you wish to aggregate. For an "average income by state", you would choose State for the grouping feature, mean for the aggregation function, and Income for the aggregated feature. To compute this in Pandas, we use the groupby and transform methods:

# %%
customer["AverageIncome"] = (
    customer.groupby("State")  # for each state
    ["Income"]                 # select the income
    .transform("mean")         # and compute its mean
)

customer[['Customer', "State", "Income", "AverageIncome"]].head(10)
# Out:
#   Customer       State  Income  AverageIncome
# 0  BU79786  Washington   56274   38122.733083
# 1  QZ44356     Arizona       0   37405.402231
# 2  AI49188      Nevada   48767   38369.605442
# 3  WW63253  California       0   37558.946667
# 4  HB64268  Washington   43836   38122.733083
# 5  OC83172      Oregon   62902   37557.283353
# 6  XZ87318      Oregon   55350   37557.283353
# 7  CF85061     Arizona       0   37405.402231
# 8  DY87989      Oregon   14072   37557.283353
# 9  BQ94931      Oregon   28812   37557.283353

# %% [markdown]
# The mean function is a built-in dataframe method, which means we can pass it as a string to transform. Other handy methods include max, min, median, var, std, and count. Here's how you could calculate the frequency with which each state occurs in the dataset:

# %%
customer["StateFreq"] = (
    customer.groupby("State")
    ["State"]
    .transform("count")
    / customer.State.count()
)

customer[['Customer', "State", "StateFreq"]].head(10)
# Out:
#   Customer       State  StateFreq
# 0  BU79786  Washington   0.087366
# 1  QZ44356     Arizona   0.186446
# 2  AI49188      Nevada   0.096562
# 3  WW63253  California   0.344865
# 4  HB64268  Washington   0.087366
# 5  OC83172      Oregon   0.284760
# 6  XZ87318      Oregon   0.284760
# 7  CF85061     Arizona   0.186446
# 8  DY87989      Oregon   0.284760
# 9  BQ94931      Oregon   0.284760

# %% [markdown]
# You could use a transform like this to create a "frequency encoding" for a categorical feature.
#
# If you're using training and validation splits, to preserve their independence, it's best to create a grouped feature using only the training set and then join it to the validation set. We can use the validation set's merge method after creating a unique set of values with `drop_duplicate` on the training set:

# %%
# Create splits
df_train = customer.sample(frac=0.5)
df_valid = customer.drop(df_train.index)

# Create the average claim amount by coverage type, on the training set
df_train["AverageClaim"] = df_train.groupby("Coverage")["ClaimAmount"].\
                                transform("mean")

# Merge the values into the validation set
df_valid = df_valid.merge(
    df_train[["Coverage", "AverageClaim"]].drop_duplicates(),
    on="Coverage",
    how="left",
)

df_valid[['Customer', "Coverage", "AverageClaim"]].head(10)
# Out:
#   Customer  Coverage  AverageClaim
# 0  QZ44356  Extended    476.544988
# 1  AI49188   Premium    645.077232
# 2  HB64268     Basic    383.706202
# 3  CF85061   Premium    645.077232
# 4  VQ65197     Basic    383.706202
# 5  DP39365   Premium    645.077232
# 6  SJ95423     Basic    383.706202
# 7  BW63560     Basic    383.706202
# 8  WC83389     Basic    383.706202
# 9  SV62436  Extended    476.544988

# %% [markdown]
# ##### Tips on Creating Features
# It's good to keep in mind your model's own strengths and weaknesses when creating features. Here are some guidelines:
# - Linear models learn sums and differences naturally, but can't learn anything more complex.
# - Ratios seem to be difficult for most models to learn. Ratio combinations often lead to some easy performance gains.
# - Linear models and neural nets generally do better with normalized features. Neural nets especially need features scaled to values not too far from 0. Tree-based models (like random forests and XGBoost) can sometimes benefit from normalization, but usually much less so.
# - Tree models can learn to approximate almost any combination of features, but when a combination is especially important they can still benefit from having it explicitly created, especially when data is limited.
# - Counts are especially helpful for tree models, since these models don't have a natural way of aggregating information across many features at once.
